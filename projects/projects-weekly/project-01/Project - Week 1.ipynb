# %%
import numpy as np
import pandas as pd

# %%
sat = pd.read_csv('/Users/amishdalal/DSI-NYC-2/projects/projects-weekly/project-01/assets/sat_scores.csv')
sat.head()
# Out:
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516

# %%
sat = sat.set_index('State')

# %%
sat['Total'] = sat['Verbal'] + sat['Math']

# %%
sat.T.to_dict()
# Out:
# {'AK': {'Math': 510, 'Rate': 51, 'Total': 1024, 'Verbal': 514},
#  'AL': {'Math': 554, 'Rate': 9, 'Total': 1113, 'Verbal': 559},
#  'AR': {'Math': 550, 'Rate': 6, 'Total': 1112, 'Verbal': 562},
#  'AZ': {'Math': 525, 'Rate': 34, 'Total': 1048, 'Verbal': 523},
#  'All': {'Math': 514, 'Rate': 45, 'Total': 1020, 'Verbal': 506},
#  'CA': {'Math': 517, 'Rate': 51, 'Total': 1015, 'Verbal': 498},
#  'CO': {'Math': 542, 'Rate': 31, 'Total': 1081, 'Verbal': 539},
#  'CT': {'Math': 510, 'Rate': 82, 'Total': 1019, 'Verbal': 509},
#  'DC': {'Math': 474, 'Rate': 56, 'Total': 956, 'Verbal': 482},
#  'DE': {'Math': 499, 'Rate': 67, 'Total': 1000, 'Verbal': 501},
#  'FL': {'Math': 499, 'Rate': 54, 'Total': 997, 'Verbal': 498},
#  'GA': {'Math': 489, 'Rate': 63, 'Total': 980, 'Verbal': 491},
#  'HI': {'Math': 515, 'Rate': 52, 'Total': 1000, 'Verbal': 485},
#  'IA': {'Math': 603, 'Rate': 5, 'Total': 1196, 'Verbal': 593},
#  'ID': {'Math': 542, 'Rate': 17, 'Total': 1085, 'Verbal': 543},
# ...

# %%
newsat = sat[sat.index != 'All']

# %%
newsat
# Out:
#        Rate  Verbal  Math  Total
# State
# CT       82     509   510   1019
# NJ       81     499   513   1012
# MA       79     511   515   1026
# NY       77     495   505   1000
# NH       72     520   516   1036
# RI       71     501   499   1000
# PA       71     500   499    999
# VT       69     511   506   1017
# ME       69     506   500   1006
# VA       68     510   501   1011
# DE       67     501   499   1000
# MD       65     508   510   1018
# NC       65     493   499    992
# GA       63     491   489    980
# IN       60     499   501   1000
# SC       57     486   488    974
# DC       56     482   474    956
# OR       55     526   526   1052
# FL       54     498   499    997
# WA       53     527   527   1054
# TX       53     493   499    992
# HI       52     485   515   1000
# AK       51     514   510   1024
# CA       51     498   517   1015
# AZ       34     523   525   1048
# NV       33     509   515   1024
# CO       31     539   542   1081
# ...
